# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
missing_values = ['s']
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values=missing_values)

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# 0               Common Core Algebra  2017             4         NaN
# 1                Living Environment  2015            16        77.9
# ...

# %%
df['Mean Score'].median()
# Out:
# 65.4

# %%
df['Mean Score'].mean()
# Out:
# 65.99896651569013

# %%
max_school = df['Mean Score'].max()

# %%
min_school = df['Mean Score'].min()

# %% [markdown]
# # This is the amount of students in the city who took each type of regents exam.

# %%
df2 = df.groupby(['Regents Exam'])['Mean Score']

# %%
df2.count()
# Out:
# Regents Exam
# Algebra2/Trigonometry               5432
# Common Core Algebra                19549
# Common Core Algebra2                4358
# Common Core English                13319
# Common Core Geometry                9546
# English                             6784
# Geometry                            4347
# Global History and Geography       14713
# Integrated Algebra                  6308
# Living Environment                 18243
# Physical Settings/Chemistry         6360
# Physical Settings/Earth Science    10397
# Physical Settings/Physics           2993
# U.S. History and Government        14752
# Name: Mean Score, dtype: int64

# %%
df2.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Regents Exam'>

# %% [markdown]
# # Based on the above graph, the most popular exam taken was Common Core Algebra

# %%
max_scores= df2.max()

# %%
min_scores = df2.min()

# %%
median_scores = df2.median()

# %% [markdown]
# # This graph shows the max, median and minimum scores for each type of regents exam in the city

# %%
max_scores.plot(), min_scores.plot(), median_scores.plot()
# Out:
# (<AxesSubplot:xlabel='Regents Exam'>,
#  <AxesSubplot:xlabel='Regents Exam'>,
#  <AxesSubplot:xlabel='Regents Exam'>)

# %%
max_scores
# Out:
# Regents Exam
# Algebra2/Trigonometry              95.2
# Common Core Algebra                96.6
# Common Core Algebra2               90.9
# Common Core English                98.3
# Common Core Geometry               92.1
# English                            95.1
# Geometry                           95.1
# Global History and Geography       97.0
# Integrated Algebra                 95.9
# Living Environment                 96.8
# Physical Settings/Chemistry        93.5
# Physical Settings/Earth Science    96.8
# Physical Settings/Physics          94.3
# U.S. History and Government        98.7
# Name: Mean Score, dtype: float64

# %%
common_core_algebra_max = 96.6

# %%
min_scores
# Out:
# Regents Exam
# Algebra2/Trigonometry              19.1
# Common Core Algebra                37.2
# Common Core Algebra2               33.6
# Common Core English                15.0
# Common Core Geometry               27.0
# English                            30.7
# Geometry                           29.0
# Global History and Geography       28.7
# Integrated Algebra                 36.7
# Living Environment                 36.5
# Physical Settings/Chemistry        30.2
# Physical Settings/Earth Science    27.1
# Physical Settings/Physics          20.8
# U.S. History and Government        33.7
# Name: Mean Score, dtype: float64

# %%
common_core_algebra_min = 37.2

# %%
# looking for the school that had the lowest Common Core Alegbra Score
# which ends up being : The Brooklyn Academy of Global Finance	

df[df['Mean Score'] == common_core_algebra_min]
# Out:
#        School DBN                                        School Name  \
# 6333       10X268              Kingsbridge International High School
# 13855      24Q600        Queens Vocational and Technical High School
# 30394      09X564                         Claremont International HS
# 30930      10X268              Kingsbridge International High School
# 36873      15K464                              Park Slope Collegiate
# 62692      05M369      Urban Assembly School for the Performing Arts
# 62957      05M685          Bread & Roses Integrated Arts High School
# 72072      10X504                                       Kennedy Yabc
# 81805      17K600                           Clara Barton High School
# 91526      27Q260          Frederick Douglass Academy VI High School
# 91860      27Q308  Robert H. Goddard High School of Communication...
# 113829     09X365                Academy for Language and Technology
# 131556     27Q334                           Epic High School - North
# ...

# %%
# looking for the school with the highest Common Core Alegbra Score
# Which ends up being Bronx High School of Science

df[df['Mean Score'] == common_core_algebra_max]
# Out:
#        School DBN                                        School Name  \
# 6859       10X445                       Bronx High School of Science
# 31889      10X445                       Bronx High School of Science
# 58075      02M475                             Stuyvesant High School
# 109555     05M692  High School for Mathematics, Science and Engin...
# 115926     10X445                       Bronx High School of Science
# 121038     15K447              The Math & Science Exploratory School
# 165364     10X445                       Bronx High School of Science
# 175503     15K447              The Math & Science Exploratory School
#
#                            School Level                 Regents Exam  Year  \
# 6859                        High school  U.S. History and Government  2015
# 31889                       High school  U.S. History and Government  2015
# 58075                       High school  U.S. History and Government  2016
# ...

# %%
# Bronx High School of Science
high_score_school = df[df['School DBN'] == '10X445']

# %%
# The Brooklyn Academy of Global Finance
low_score_school = df[df['School DBN'] == '16K688']

# %%
hsp = high_score_school.groupby(['Regents Exam'])['Mean Score'].median()

# %%
lsp = low_score_school.groupby(['Regents Exam'])['Mean Score'].median()

# %% [markdown]
# # The median scores for the schools that scored lowest and highest in the Common Core Algebra, show that they perfromed similary in other subjects as well.

# %%
hsp.plot(), lsp.plot()
# Out:
# (<AxesSubplot:xlabel='Regents Exam'>, <AxesSubplot:xlabel='Regents Exam'>)

# %% [markdown]
# The above graph shows the median for each different regents, the blue being the top scoring school in the common core algebra regents and the orange being the lowest scoring school in the common core algebra regents.

# %%
hsp.plot(), median_scores.plot()
# Out:
# (<AxesSubplot:xlabel='Regents Exam'>, <AxesSubplot:xlabel='Regents Exam'>)

# %% [markdown]
# The school that scored highest in Common Core Alegbra also scored significantly higher than the city's median scores.

# %%
lsp.plot(),median_scores.plot()
# Out:
# (<AxesSubplot:xlabel='Regents Exam'>, <AxesSubplot:xlabel='Regents Exam'>)

# %% [markdown]
# The school who scored lowest in Common Core Alegbra scored lower than the median of the city for all exams, although that gap between their scores and the city's median is not as great as the higher preforming school's was.
